# %%
import pandas as pd
import numpy as np
import yfinance as yf
import investpy as inv

# %% [markdown]
# importando dados da b3

# %%
br = inv.stocks.get_stocks(country='brazil')
br
# Out:
#     country                name                               full_name  \
# 0    brazil       ABC BRASIL PN                     Banco ABC Brasil SA
# 1    brazil       BRASILAGRO ON                   BrasilAgro - Co ON NM
# 2    brazil          RUMO ON NM  RUMO Logistica Operadora Multimodal SA
# 3    brazil       ALPARGATAS ON                           Alpargatas SA
# 4    brazil       ALPARGATAS PN                           Alpargatas SA
# ..      ...                 ...                                     ...
# 744  brazil  Integral Brei Reit     Fdo Inv Imob Fof Integral Brei Reit
# 745  brazil             Vbi Cri                  Fi Imobiliario Vbi Cri
# 746  brazil        Hedge Realty      Hedge Realty Devl Fdo Inv Imob Etf
# 747  brazil              Rb Cap      Rb Cap Desenvolvimento Res Iii Fii
# 748  brazil            Treecorp          Treecorp Real Estate Fii I Etf
#
#              isin currency  symbol
# 0    BRABCBACNPR4      BRL   ABCB4
# 1    BRAGROACNOR7      BRL   AGRO3
# 2    BRRAILACNOR9      BRL   RAIL3
# 3    BRALPAACNOR0      BRL   ALPA3
# 4    BRALPAACNPR7      BRL   ALPA4
# ..            ...      ...     ...
# 744  BRIBFFCTF007      BRL  IBFF11
# 745  BRCVBICTF001      BRL  CVBI11
# 746  BRHRDFCTF000      BRL  HRDF11
# 747  BRRSPDCTF006      BRL  RSPD11
# 748  BRTCPFCTF001      BRL  TCPF11
#
# [749 rows x 6 columns]

# %%
br['symbol']
# Out:
# 0       ABCB4
# 1       AGRO3
# 2       RAIL3
# 3       ALPA3
# 4       ALPA4
#         ...
# 744    IBFF11
# 745    CVBI11
# 746    HRDF11
# 747    RSPD11
# 748    TCPF11
# Name: symbol, Length: 749, dtype: object

# %% [markdown]
# filtrando ações

# %%
carteira = []
for a in br['symbol']:
    if len(a) <= 5:
        carteira.append(a +'.SA')

# %%
carteira
# Out:
# ['ABCB4.SA',
#  'AGRO3.SA',
#  'RAIL3.SA',
#  'ALPA3.SA',
#  'ALPA4.SA',
#  'ALSO3.SA',
#  'AMAR3.SA',
#  'ABEV3.SA',
#  'ADHM3.SA',
#  'ARZZ3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBRK3.SA',
#  'BEEF3.SA',
#  'BPHA3.SA',
#  'BPAN4.SA',
#  'BRAP3.SA',
#  'BRAP4.SA',
#  'BRFS3.SA',
#  'APER3.SA',
#  'BRKM3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BRPR3.SA',
#  'BRSR6.SA',
#  'OIBR3.SA',
#  'OIBR4.SA',
#  'BTOW3.SA',
#  'B3SA3.SA',
#  'CAMB4.SA',
#  'CARD3.SA',
#  'CCPR3.SA',
#  'CCRO3.SA',
#  'CEDO4.SA',
#  'CEED3.SA',
#  'CESP6.SA',
#  'CGAS5.SA',
#  'CGRA4.SA',
#  'CIEL3.SA',
#  'CMIG3.SA',
#  'CMIG4.SA',
#  'COCE5.SA',
#  'CPFE3.SA',
#  'CPLE3.SA',
#  'CPLE6.SA',
#  'CRDE3.SA',
#  'CSAN3.SA',
#  'CSMG3.SA',
#  'CSNA3.SA',
#  'LIQO3.SA',
#  'CTNM4.SA',
#  'CYRE3.SA',
#  'DASA3.SA',
#  'DIRR3.SA',
#  'DTEX3.SA',
#  'ECOR3.SA',
#  'EEEL3.SA',
#  'ELEK4.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENBR3.SA',
#  'ENGI4.SA',
#  'EQTL3.SA',
#  'YDUQ3.SA',
#  'ETER3.SA',
#  'EUCA4.SA',
#  'EVEN3.SA',
#  'EZTC3.SA',
#  'FESA4.SA',
#  'FHER3.SA',
#  'TASA4.SA',
#  'FLRY3.SA',
#  'FRIO3.SA',
#  'TIET3.SA',
#  'TIET4.SA',
#  'GFSA3.SA',
#  'GGBR3.SA',
#  'GGBR4.SA',
#  'GOAU3.SA',
#  'GOAU4.SA',
#  'GOLL4.SA',
#  'GRND3.SA',
#  'GSHP3.SA',
#  'HBOR3.SA',
#  'HGTX3.SA',
#  'PRIO3.SA',
#  'HYPE3.SA',
#  'IDNT3.SA',
#  'IDVL4.SA',
#  'IGTA3.SA',
#  'MEAL3.SA',
#  'INEP3.SA',
#  'INEP4.SA',
#  'ITSA3.SA',
#  'ITSA4.SA',
#  'ITUB3.SA',
#  'ITUB4.SA',
#  'JBSS3.SA',
#  'JFEN3.SA',
#  'JHSF3.SA',
#  'JSLG3.SA',
#  'KEPL3.SA',
#  'KLBN4.SA',
#  'LAME3.SA',
#  'LAME4.SA',
#  'LEVE3.SA',
#  'LIGT3.SA',
#  'LLIS3.SA',
#  'LOGN3.SA',
#  'LPSB3.SA',
#  'LREN3.SA',
#  'LUPA3.SA',
#  'MDIA3.SA',
#  'MGEL4.SA',
#  'MGLU3.SA',
#  'MILS3.SA',
#  'MMXM3.SA',
#  'ENEV3.SA',
#  'MRFG3.SA',
#  'MRVE3.SA',
#  'MTIG4.SA',
#  'MULT3.SA',
#  'MYPK3.SA',
#  'NATU3.SA',
#  'ODPV3.SA',
#  'OSXB3.SA',
#  'PCAR4.SA',
#  'PDGR3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'PFRM3.SA',
#  'PINE4.SA',
#  'PLAS3.SA',
#  'PMAM3.SA',
#  'POMO3.SA',
#  'POMO4.SA',
#  'POSI3.SA',
#  'PSSA3.SA',
#  'PTBL3.SA',
#  'PTNT4.SA',
#  'ENAT3.SA',
#  'QUAL3.SA',
#  'RAPT3.SA',
#  'RAPT4.SA',
#  'RDNI3.SA',
#  'RENT3.SA',
#  'FRTA3.SA',
#  'ROMI3.SA',
#  'RSID3.SA',
#  'SBSP3.SA',
#  'SCAR3.SA',
#  'SGPS3.SA',
#  'SHOW3.SA',
#  'SLCE3.SA',
#  'SLED4.SA',
#  'SMTO3.SA',
#  'EGIE3.SA',
#  'TCSA3.SA',
#  'TECN3.SA',
#  'TEKA4.SA',
#  'TGMA3.SA',
#  'TIMP3.SA',
#  'TOTS3.SA',
#  'TPIS3.SA',
#  'TRIS3.SA',
#  'TRPL4.SA',
#  'TRPN3.SA',
#  'UGPA3.SA',
#  'UNIP3.SA',
#  'UNIP6.SA',
#  'USIM3.SA',
#  'USIM5.SA',
#  'TESA3.SA',
#  'VALE3.SA',
#  'VIVR3.SA',
#  'VIVT3.SA',
#  'VIVT4.SA',
#  'VLID3.SA',
#  'WEGE3.SA',
#  'BRSR5.SA',
#  'CESP5.SA',
#  'ELPL3.SA',
#  'SANB4.SA',
#  'STBP3.SA',
#  'CCXC3.SA',
#  'CESP3.SA',
#  'CGRA3.SA',
#  'CLSC4.SA',
#  'COCE3.SA',
#  'TASA3.SA',
#  'COGN3.SA',
#  'LCAM3.SA',
#  'RADL3.SA',
#  'UCAS3.SA',
#  'ANIM3.SA',
#  'BBSE3.SA',
#  'BSEV3.SA',
#  'CPRE3.SA',
#  'CVCB3.SA',
#  'LINX3.SA',
#  'SEER3.SA',
#  'SMLS3.SA',
#  'TUPY3.SA',
#  'SQIA3.SA',
#  'BIOM3.SA',
#  'NUTR3.SA',
#  'BAZA3.SA',
#  'TCNO3.SA',
#  'SANB3.SA',
#  'SEDU3.SA',
#  'FRAS3.SA',
#  'GEPA4.SA',
#  'OFSA3.SA',
#  'RLOG3.SA',
#  'TOYB3.SA',
#  'WIZS3.SA',
#  'GUAR3.SA',
#  'IGBR3.SA',
#  'TELB4.SA',
#  'WHRL3.SA',
#  'SHUL4.SA',
#  'ATOM3.SA',
#  'SAPR4.SA',
#  'CRIV4.SA',
#  'RPMG3.SA',
#  'BRSR3.SA',
#  'SNSY5.SA',
#  'DMMO3.SA',
#  'AZEV4.SA',
#  'BAHI3.SA',
#  'BALM4.SA',
#  'BAUH4.SA',
#  'BDLL4.SA',
#  'BEES3.SA',
#  'BEES4.SA',
#  'BGIP4.SA',
#  'BMEB3.SA',
#  'BMEB4.SA',
#  'BMIN3.SA',
#  'BMIN4.SA',
#  'BMKS3.SA',
#  'BNBR3.SA',
#  'BOBR4.SA',
#  'BRIV3.SA',
#  'BRIV4.SA',
#  'BSLI4.SA',
#  'BTTL3.SA',
#  'CBEE3.SA',
#  'CEEB3.SA',
#  'CEEB5.SA',
#  'CELP3.SA',
#  'CELP5.SA',
#  'CEPE5.SA',
#  'CGAS3.SA',
#  'CRIV3.SA',
#  'CRPG5.SA',
#  'CRPG6.SA',
#  'CSRN3.SA',
#  'CTKA4.SA',
#  'CTNM3.SA',
#  'CTSA3.SA',
#  'CTSA4.SA',
#  'DOHL4.SA',
#  'DTCY3.SA',
#  'EALT4.SA',
#  'EKTR4.SA',
#  'ELEK3.SA',
#  'EMAE4.SA',
#  'ENGI3.SA',
#  'ENMT3.SA',
#  'ESTR4.SA',
#  'FESA3.SA',
#  'GPCP3.SA',
#  'HAGA4.SA',
#  'HBTS5.SA',
#  'HETA4.SA',
#  'HOOT4.SA',
#  'IDVL3.SA',
#  'JBDU3.SA',
#  'JBDU4.SA',
#  'JOPA3.SA',
#  'JOPA4.SA',
#  'KLBN3.SA',
#  'MEND5.SA',
#  'MNDL3.SA',
#  'MNPR3.SA',
#  'MTSA4.SA',
#  'MWET4.SA',
#  'PEAB4.SA',
#  'PNVL3.SA',
#  'PNVL4.SA',
#  'RANI3.SA',
#  'RANI4.SA',
#  'RCSL3.SA',
#  'RCSL4.SA',
#  'REDE3.SA',
#  'RPAD5.SA',
#  'RPAD6.SA',
#  'WLMM3.SA',
#  'WLMM4.SA',
#  'SLED3.SA',
#  'SOND5.SA',
#  'SOND6.SA',
#  'SPRI3.SA',
#  'TCNO4.SA',
#  'TELB3.SA',
#  'TOYB4.SA',
#  'TRPL3.SA',
#  'UNIP5.SA',
#  'USIM6.SA',
#  'VULC3.SA',
#  'VVAR3.SA',
#  'WHRL4.SA',
#  'AALR3.SA',
#  'AFLT3.SA',
#  'BGIP3.SA',
#  'CEBR3.SA',
#  'CEDO3.SA',
#  'GPAR3.SA',
#  'MAPT3.SA',
#  'PATI4.SA',
#  'RPAD3.SA',
#  'VSPT3.SA',
#  'MOVI3.SA',
#  'PARD3.SA',
#  'RNEW3.SA',
#  'RNEW4.SA',
#  'AZUL4.SA',
#  'TEND3.SA',
#  'CRFB3.SA',
#  'OMGE3.SA',
#  'IRBR3.SA',
#  'GEPA3.SA',
#  'SAPR3.SA',
#  'CAML3.SA',
#  'SUZB3.SA',
#  'BRDT3.SA',
#  'NEOE3.SA',
#  'BKBR3.SA',
#  'GFSA1.SA',
#  'TXRX4.SA',
#  'MSPA3.SA',
#  'HAPV3.SA',
#  'GNDI3.SA',
#  'BIDI4.SA',
#  'JPSA3.SA',
#  'TAEE4.SA',
#  'ALUP3.SA',
#  'ALUP4.SA',
#  'LOGG3.SA',
#  'TAEE3.SA',
#  'AZEV3.SA',
#  'AHEB3.SA',
#  'BALM3.SA',
#  'BPAC3.SA',
#  'EALT3.SA',
#  'ECPR3.SA',
#  'HAGA3.SA',
#  'ITEC3.SA',
#  'LIPR3.SA',
#  'PATI3.SA',
#  'PEAB3.SA',
#  'SULA3.SA',
#  'BPAC5.SA',
#  'BRGE6.SA',
#  'CELP6.SA',
#  'CELP7.SA',
#  'CORR4.SA',
#  'EEEL4.SA',
#  'ENMT4.SA',
#  'LUXM4.SA',
#  'MEND6.SA',
#  'MERC4.SA',
#  'RSUL4.SA',
#  'SULA4.SA',
#  'JBDU1.SA',
#  'JBDU2.SA',
#  'BBDC3.SA',
#  'CNTO3.SA',
#  'VAMO3.SA',
#  'IDVL9.SA',
#  'MOAR3.SA',
#  'BIDI3.SA',
#  'TIET2.SA',
#  'TCR11.SA',
#  'VIVA3.SA',
#  'CEAB3.SA',
#  'BMGB4.SA']

# %%
dt = yf.download(carteira, start='2023-01-01')['Close']
# Out:
# [*********             18%%                      ]  70 of 389 completedFailed to get ticker 'EEEL3.SA' reason: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# [*********             18%%                      ]  71 of 389 completedFailed to get ticker 'CELP5.SA' reason: HTTPSConnectionPool(host='guce.yahoo.com', port=443): Read timed out. (read timeout=30)
# [*********             19%%                      ]  72 of 389 completedFailed to get ticker 'TCNO3.SA' reason: HTTPSConnectionPool(host='guce.yahoo.com', port=443): Read timed out. (read timeout=30)
# [*********************100%%**********************]  389 of 389 completed
#
# 88 Failed downloads:
# ['EEEL4.SA', 'CCXC3.SA', 'LCAM3.SA', 'SEDU3.SA', 'TIET4.SA', 'CCPR3.SA', 'SPRI3.SA', 'HGTX3.SA', 'BIDI4.SA', 'CELP3.SA', 'CRDE3.SA', 'CELP7.SA', 'CELP6.SA', 'GFSA1.SA', 'ELEK3.SA', 'TOYB3.SA', 'IDVL9.SA', 'EEEL3.SA', 'CELP5.SA', 'TCNO3.SA', 'RLOG3.SA', 'IDNT3.SA', 'JBDU3.SA', 'JBDU1.SA', 'GPCP3.SA', 'TRPN3.SA', 'BTOW3.SA', 'SMLS3.SA', 'FRTA3.SA', 'VIVT4.SA', 'CESP5.SA', 'VVAR3.SA', 'TIET2.SA', 'TESA3.SA', 'GNDI3.SA', 'MTIG4.SA', 'LAME4.SA', 'DMMO3.SA', 'SULA4.SA', 'JBDU4.SA', 'MEND6.SA', 'PCAR4.SA', 'CESP6.SA', 'TIMP3.SA', 'LLIS3.SA', 'IDVL4.SA', 'PARD3.SA', 'RANI4.SA', 'CAMB4.SA', 'BIDI3.SA', 'IGTA3.SA', 'LINX3.SA', 'OMGE3.SA', 'CNTO3.SA', 'CESP3.SA', 'JBDU2.SA', 'BBRK3.SA', 'PNVL4.SA', 'TIET3.SA', 'TCR11.SA', 'ELEK4.SA', 'CPRE3.SA', 'MEND5.SA', 'ALSO3.SA', 'SQIA3.SA', 'DTEX3.SA', 'ITEC3.SA', 'LAME3.SA', 'CEPE5.SA', 'TCNO4.SA', 'JPSA3.SA', 'BSEV3.SA', 'MMXM3.SA', 'BKBR3.SA', 'ELPL3.SA', 'IDVL3.SA', 'ENBR3.SA', 'BRDT3.SA', 'BRML3.SA', 'TOYB4.SA', 'CARD3.SA', 'SULA3.SA', 'NATU3.SA', 'BTTL3.SA', 'WIZS3.SA', 'LIQO3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['HYPE3.SA']: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='guce.yahoo.com', port=443): Read timed out. (read timeout=30)"))
# ['BGIP3.SA']: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='www.yahoo.com', port=443): Read timed out. (read timeout=30)"))

# %%
dt
# Out:
# Ticker       AALR3.SA   ABCB4.SA  ABEV3.SA  ADHM3.SA  AFLT3.SA   AGRO3.SA  \
# Date
# 2023-01-02  21.120001  18.237885     14.19      1.56      9.30  29.110001
# 2023-01-03  21.190001  17.511902     14.17      1.56      9.31  28.290001
# 2023-01-04  21.200001  17.570765     14.25      1.56      9.13  27.660000
# 2023-01-05  21.360001  18.571444     14.29      1.56      9.13  27.610001
# 2023-01-06  21.290001  18.620497     14.32      1.56      9.13  27.820000
# ...               ...        ...       ...       ...       ...        ...
# 2024-07-16  12.470000  22.959999     11.70      1.56      7.23  26.959999
# 2024-07-17  12.610000  22.959999     11.82      1.56      7.23  28.200001
# 2024-07-18  12.410000  22.590000     11.67      1.56      7.21  27.790001
# 2024-07-19  12.390000  22.590000     11.73      1.56      7.21  27.870001
# 2024-07-22  12.400000  23.080000     11.84       NaN       NaN  27.330000
#
# Ticker      AHEB3.SA  ALPA3.SA  ALPA4.SA  ALSO3.SA  ...  VSPT3.SA   VULC3.SA  \
# Date                                                ...
# 2023-01-02      20.0     11.70     14.33       NaN  ...       1.5  11.741402
# 2023-01-03      20.0     10.89     13.40       NaN  ...       1.5  11.386200
# 2023-01-04      20.0     11.23     13.49       NaN  ...       1.5  11.356599
# 2023-01-05      20.0     11.25     13.86       NaN  ...       1.5  11.672335
# 2023-01-06      20.0     11.45     13.87       NaN  ...       1.5  11.652601
# ...              ...       ...       ...       ...  ...       ...        ...
# 2024-07-16      35.0      9.00      9.20       NaN  ...       1.5  15.900000
# 2024-07-17      35.0      9.15      9.28       NaN  ...       1.5  15.800000
# 2024-07-18      35.0      8.92      8.91       NaN  ...       1.5  15.800000
# 2024-07-19      35.0      9.13      8.87       NaN  ...       1.5  15.620000
# 2024-07-22      35.0      9.06      8.92       NaN  ...       NaN  15.650000
#
# Ticker      VVAR3.SA   WEGE3.SA  WHRL3.SA  WHRL4.SA  WIZS3.SA  WLMM3.SA  \
# Date
# 2023-01-02       NaN  38.099998      4.60      4.92       NaN     21.50
# 2023-01-03       NaN  37.150002      4.76      4.92       NaN     21.50
# 2023-01-04       NaN  37.400002      4.77      4.96       NaN     21.50
# 2023-01-05       NaN  37.480000      4.74      4.94       NaN     21.50
# 2023-01-06       NaN  38.029999      4.76      4.97       NaN     21.50
# ...              ...        ...       ...       ...       ...       ...
# 2024-07-16       NaN  46.680000      4.51      4.53       NaN     25.51
# 2024-07-17       NaN  47.049999      4.51      4.54       NaN     25.51
# 2024-07-18       NaN  47.400002      4.51      4.54       NaN     25.51
# 2024-07-19       NaN  47.290001      4.44      4.55       NaN     25.51
# 2024-07-22       NaN  47.049999       NaN      4.53       NaN     24.40
#
# Ticker       WLMM4.SA  YDUQ3.SA
# Date
# 2023-01-02  22.299999      9.79
# 2023-01-03  21.500000      9.17
# 2023-01-04  20.049999      9.29
# 2023-01-05  19.860001      9.41
# 2023-01-06  20.049999      9.75
# ...               ...       ...
# 2024-07-16  31.500000     12.05
# 2024-07-17  31.309999     11.90
# 2024-07-18  31.600000     11.51
# 2024-07-19  31.900000     11.30
# 2024-07-22  31.600000     11.43
#
# [388 rows x 389 columns]
